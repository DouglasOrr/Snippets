# %%
# %load_ext autoreload
# %autoreload 2
import hover as H
from IPython.display import display, update_display
import numpy as np
import itertools as it
import collections
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import torch as T
import time
sns.set_context('talk')

# %%
def plot_lifetime_dist(df):
    plt.figure(figsize=(10, 6))
    bins = np.logspace(np.log10(.6), np.log10(20), 50)
    names = sorted(set(df.name))
    for name in names:
        sns.distplot(df.lifetime[df.name == name], kde=False, bins=bins)
    plt.gca().set_xscale('log')
    plt.legend(names)

# %%
class Log:
    def __init__(self):
        self._t = 0
        self._logs = collections.defaultdict(lambda: ([], []))

    def append(self, name, value):
        ts, values = self._logs[name]
        ts.append(self._t)
        values.append(value)
        
    def tick(self):
        self._t += 1
        
    def show(self):
        for name, (ts, values) in self._logs.items():
            plt.figure(figsize=(10, 6))
            plt.scatter(ts, values)
            plt.title(name)

# %%
# %%prun

agents = dict(
    **{"constant_up_{}".format(f): H.IntegratorController(H.constant_agent(f, f))
       for f in [0.25, 0.33, 0.5]},
    **{"constant_{:02b}".format(i): H.constant_agent(bool(i & 0x01), bool(i & 0x02))
       for i in range(4)},
)
df = pd.DataFrame.from_dict(
    [dict(name=name, lifetime=H.single_game_lifetime(agent, 20))
     for name, agent in agents.items()
     for _ in range(100)])
display(df.groupby('name').mean())

plt.figure(figsize=(10, 6))
bins = np.logspace(np.log10(.6), np.log10(20), 50)
for name in agents:
    sns.distplot(df.lifetime[df.name == name], kde=False, bins=bins)
plt.gca().set_xscale('log')
plt.legend(agents)
# Out:
#                   lifetime
# name
# constant_00         1.4800
# constant_01         0.8398
# constant_10         0.8364
# constant_11         1.0333
# constant_up_0.25    2.8400
# constant_up_0.33    5.1582
# constant_up_0.5     2.1376
#          3227026 function calls (3217887 primitive calls) in 4.269 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    143253    1.297    0.000    1.454    0.000 hover.py:125(step)
#    143953    0.577    0.000    1.289    0.000 hover.py:134(state)
#       700    0.415    0.001    3.850    0.005 hover.py:148(single_game_lifetime)
#    143953    0.224    0.000    0.261    0.000 hover.py:144(in_bounds)
#    101358    0.187    0.000    0.212    0.000 hover.py:166(__call__)
#    143953    0.112    0.000    0.112    0.000 {built-in method Box2D._Box2D.b2Body___GetPosition}
#    143953    0.107    0.000    0.107    0.000 {built-in method Box2D._Box2D.b2Body___GetLinearVelocity}
#    143953    0.076    0.000    0.188    0.000 Box2D.py:3909(__GetPosition)
#    143253    0.074    0.000    0.126    0.000 Box2D.py:4068(__GetMass)
#       700    0.069    0.000    0.207    0.000 hover.py:74(__init__)
#    144423    0.061    0.000    0.061    0.000 {built-in method __new__ of type object at 0x5640069d8e00}
#    143953    0.061    0.000    0.105    0.000 Box2D.py:3987(__GetAngularVelocity)
#    143953    0.061    0.000    0.168    0.000 Box2D.py:3962(__GetLinearVelocity)
#    143953    0.058    0.000    0.105    0.000 Box2D.py:3919(__GetAngle)
#    143253    0.051    0.000    0.051    0.000 {built-in method Box2D._Box2D.b2Body___GetMass}
#    143953    0.046    0.000    0.046    0.000 {built-in method Box2D._Box2D.b2Body___GetAngle}
#    143953    0.044    0.000    0.044    0.000 {built-in method Box2D._Box2D.b2Body___GetAngularVelocity}
#    287698    0.037    0.000    0.037    0.000 {built-in method builtins.abs}
#    143253    0.037    0.000    0.037    0.000 hover.py:178(<lambda>)
# 12776/12762    0.037    0.000    0.037    0.000 {built-in method numpy.core.multiarray.array}
#    214096    0.032    0.000    0.032    0.000 Box2D.py:883(__len__)
#      1400    0.018    0.000    0.023    0.000 Box2D.py:3307(__set_vertices)
#     42989    0.014    0.000    0.021    0.000 {built-in method builtins.isinstance}
# 12880/8440    0.012    0.000    0.021    0.000 artist.py:230(stale)
#      2707    0.012    0.000    0.012    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      9324    0.011    0.000    0.011    0.000 transforms.py:88(__init__)
#      5600    0.011    0.000    0.022    0.000 Box2D.py:143(_init_kwargs)
#      1050    0.010    0.000    0.020    0.000 transforms.py:2007(rotate)
#      1036    0.010    0.000    0.022    0.000 colors.py:176(_to_rgba_no_colorcycle)
#      4615    0.010    0.000    0.011    0.000 transforms.py:169(set_children)
#      1400    0.010    0.000    0.062    0.000 Box2D.py:4537(__CreateShapeFixture)
#      1050    0.009    0.000    0.150    0.000 patches.py:707(_update_patch_transform)
#      1400    0.009    0.000    0.046    0.000 Box2D.py:6071(CreateBody)
# 1730/1729    0.008    0.000    0.027    0.000 transforms.py:1783(__eq__)
#     10559    0.008    0.000    0.033    0.000 {built-in method builtins.setattr}
#      3521    0.008    0.000    0.008    0.000 {built-in method numpy.core.multiarray.dot}
#      3153    0.007    0.000    0.018    0.000 transforms.py:2396(__init__)
#      2497    0.007    0.000    0.039    0.000 colors.py:142(to_rgba)
# 14141/14120    0.007    0.000    0.009    0.000 {built-in method builtins.getattr}
# 3461/3265    0.007    0.000    0.010    0.000 transforms.py:142(_invalidate_internal)
#      4900    0.007    0.000    0.010    0.000 arrayprint.py:527(_extendLine)
#      3854    0.007    0.000    0.027    0.000 transforms.py:2577(composite_transform_factory)
#      5405    0.007    0.000    0.007    0.000 __init__.py:930(__getitem__)
#      1448    0.007    0.000    0.018    0.000 transforms.py:771(__init__)
#       357    0.006    0.000    0.067    0.000 patches.py:49(__init__)
#      2100    0.006    0.000    0.006    0.000 {built-in method Box2D._Box2D.b2Body___CreateFixture}
#      1050    0.006    0.000    0.026    0.000 transforms.py:2023(rotate_deg)
#      8365    0.006    0.000    0.006    0.000 {built-in method builtins.hasattr}
#      2115    0.006    0.000    0.030    0.000 transforms.py:2055(translate)
#         7    0.006    0.001    0.017    0.002 arrayprint.py:535(_formatArray)
#      4343    0.005    0.000    0.013    0.000 transforms.py:1767(__init__)
# 3101/1386    0.005    0.000    0.023    0.000 transforms.py:2448(_iter_break_from_left_to_right)
#         1    0.005    0.005    3.855    3.855 <string>:10(<listcomp>)
#      5180    0.005    0.000    0.005    0.000 colors.py:228(<genexpr>)
#         7    0.005    0.001    0.367    0.052 _axes.py:2013(bar)
#       700    0.005    0.000    0.014    0.000 Box2D.py:4614(CreateFixturesFromShapes)
#      2100    0.005    0.000    0.016    0.000 Box2D.py:3241(__init__)
#        48    0.005    0.000    0.005    0.000 {built-in method builtins.sum}
# 7985/7984    0.004    0.000    0.004    0.000 {built-in method builtins.iter}
#      2567    0.004    0.000    0.004    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       343    0.004    0.000    0.212    0.001 _base.py:2040(_update_patch_limits)
#       445    0.004    0.000    0.006    0.000 artist.py:87(__init__)
#      1400    0.004    0.000    0.067    0.000 Box2D.py:4564(CreatePolygonFixture)
#      2100    0.004    0.000    0.013    0.000 Box2D.py:4823(__init__)
#      1089    0.004    0.000    0.035    0.000 artist.py:854(update)
#      1050    0.004    0.000    0.059    0.000 transforms.py:2043(rotate_deg_around)
#      3258    0.004    0.000    0.006    0.000 __init__.py:517(iterable)
# 2422/1386    0.004    0.000    0.034    0.000 transforms.py:2442(__eq__)
#      2100    0.004    0.000    0.004    0.000 {built-in method Box2D._Box2D.b2PolygonShape_swiginit}
#      3265    0.004    0.000    0.014    0.000 transforms.py:131(invalidate)
#      3854    0.004    0.000    0.032    0.000 transforms.py:1281(__add__)
# 24795/24724    0.004    0.000    0.004    0.000 {built-in method builtins.len}
#       371    0.004    0.000    0.071    0.000 artist.py:650(set_clip_path)
#      1400    0.004    0.000    0.017    0.000 Box2D.py:3778(__init__)
#      1853    0.004    0.000    0.017    0.000 fromnumeric.py:1973(all)
#      1063    0.004    0.000    0.014    0.000 patches.py:273(_set_edgecolor)
#      1050    0.004    0.000    0.034    0.000 patches.py:726(_convert_units)
#      3098    0.003    0.000    0.006    0.000 abc.py:180(__instancecheck__)
#      3069    0.003    0.000    0.008    0.000 artist.py:288(pchanged)
#      2100    0.003    0.000    0.003    0.000 {built-in method Box2D._Box2D.b2FixtureDef_swiginit}
#      1400    0.003    0.000    0.003    0.000 {built-in method Box2D._Box2D.b2World___CreateBody}
#       700    0.003    0.000    0.003    0.000 {method 'rand' of 'mtrand.RandomState' objects}
#       360    0.003    0.000    0.006    0.000 path.py:198(_update_values)
#      3269    0.003    0.000    0.003    0.000 _weakrefset.py:70(__contains__)
#      2283    0.003    0.000    0.011    0.000 artist.py:66(_stale_axes_callback)
#      3155    0.003    0.000    0.005    0.000 six.py:586(iteritems)
#      2166    0.003    0.000    0.018    0.000 artist.py:184(convert_xunits)
#       700    0.003    0.000    0.003    0.000 {built-in method Box2D._Box2D.b2World_swiginit}
#      1052    0.003    0.000    0.021    0.000 transforms.py:833(from_extents)
#      2497    0.003    0.000    0.009    0.000 colors.py:107(_is_nth_color)
#       350    0.003    0.000    0.062    0.000 transforms.py:1336(contains_branch)
#      2855    0.003    0.000    0.020    0.000 units.py:118(is_numlike)
#      1436    0.003    0.000    0.009    0.000 transforms.py:1912(__init__)
#      2880    0.003    0.000    0.011    0.000 __init__.py:583(is_numlike)
#     12880    0.003    0.000    0.003    0.000 artist.py:715(get_animated)
#       350    0.003    0.000    0.003    0.000 {built-in method matplotlib._path.update_path_extents}
#      1400    0.003    0.000    0.003    0.000 {built-in method Box2D._Box2D.b2BodyDef_swiginit}
#      2157    0.003    0.000    0.014    0.000 artist.py:193(convert_yunits)
#       700    0.003    0.000    0.007    0.000 Box2D.py:5642(__init__)
#       352    0.003    0.000    0.069    0.000 patches.py:664(__init__)
#       700    0.002    0.000    0.037    0.000 Box2D.py:6061(CreateStaticBody)
#      1052    0.002    0.000    0.008    0.000 transforms.py:2660(__init__)
#      1450    0.002    0.000    0.002    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      2855    0.002    0.000    0.022    0.000 axis.py:1515(convert_units)
#      2100    0.002    0.000    0.008    0.000 Box2D.py:4466(__CreateFixture)
#     11981    0.002    0.000    0.002    0.000 {method 'items' of 'dict' objects}
#      1063    0.002    0.000    0.035    0.000 patches.py:301(_set_facecolor)
#       350    0.002    0.000    0.004    0.000 transforms.py:436(bounds)
#  2086/700    0.002    0.000    0.003    0.000 transforms.py:2454(depth)
#      9071    0.002    0.000    0.002    0.000 artist.py:202(axes)
#      2303    0.002    0.000    0.013    0.000 {method 'all' of 'numpy.ndarray' objects}
#       343    0.002    0.000    0.286    0.001 _base.py:2022(add_patch)
#      1458    0.002    0.000    0.002    0.000 re.py:286(_compile)
#      1096    0.002    0.000    0.008    0.000 {built-in method builtins.any}
#       700    0.002    0.000    0.015    0.000 Box2D.py:6041(CreateDynamicBody)
#      1400    0.002    0.000    0.006    0.000 Box2D.py:4648(CreateFixture)
#      1457    0.002    0.000    0.002    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#       707    0.002    0.000    0.106    0.000 patches.py:194(get_transform)
#       720    0.002    0.000    0.026    0.000 artist.py:858(_update_property)
#     10216    0.002    0.000    0.002    0.000 {method 'rstrip' of 'str' objects}
#       700    0.002    0.000    0.002    0.000 {built-in method Box2D._Box2D.new_b2World}
#      2157    0.002    0.000    0.004    0.000 figure.py:58(_stale_figure_callback)
#       693    0.002    0.000    0.021    0.000 transforms.py:2334(__eq__)
#      2100    0.002    0.000    0.002    0.000 Box2D.py:4863(__del__)
#       343    0.002    0.000    0.011    0.000 transforms.py:2498(get_affine)
#      2072    0.002    0.000    0.004    0.000 transforms.py:1309(_iter_break_from_left_to_right)
#       350    0.002    0.000    0.005    0.000 transforms.py:869(update_from_path)
#      2100    0.002    0.000    0.002    0.000 {built-in method Box2D._Box2D.new_b2PolygonShape}
#      1310    0.001    0.000    0.003    0.000 six.py:583(itervalues)
#      8179    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#      1457    0.001    0.000    0.005    0.000 re.py:169(match)
#       360    0.001    0.000    0.010    0.000 path.py:101(__init__)
#       694    0.001    0.000    0.006    0.000 artist.py:901(set_label)
#      1400    0.001    0.000    0.003    0.000 Box2D.py:3359(__set_vertices_internal)
#       353    0.001    0.000    0.006    0.000 _base.py:954(_set_artist_props)
#        22    0.001    0.000    0.003    0.000 _base.py:2476(<listcomp>)
#      2574    0.001    0.000    0.003    0.000 numeric.py:534(asanyarray)
#      2329    0.001    0.000    0.006    0.000 numeric.py:463(asarray)
#      4714    0.001    0.000    0.001    0.000 artist.py:940(sticky_edges)
#         1    0.001    0.001    4.354    4.354 {built-in method builtins.exec}
#      1068    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       343    0.001    0.000    0.015    0.000 transforms.py:905(update_from_data_xy)
#       345    0.001    0.000    0.017    0.000 transforms.py:1425(transform)
#       343    0.001    0.000    0.017    0.000 _base.py:2136(update_datalim)
#       350    0.001    0.000    0.001    0.000 {built-in method matplotlib._path.affine_transform}
#        44    0.001    0.000    0.020    0.000 _base.py:2486(handle_single_axis)
#      2303    0.001    0.000    0.011    0.000 _methods.py:40(_all)
#       357    0.001    0.000    0.003    0.000 patches.py:373(set_linestyle)
#       350    0.001    0.000    0.001    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#      1400    0.001    0.000    0.001    0.000 {built-in method Box2D._Box2D.b2PolygonShape___set_vertices_internal}
#         7    0.001    0.000    0.412    0.059 _axes.py:6328(hist)
#      1037    0.001    0.000    0.001    0.000 {built-in method numpy.core.multiarray.can_cast}
#       343    0.001    0.000    0.007    0.000 transforms.py:2680(get_matrix)
#         7    0.001    0.000    0.001    0.000 {pandas._libs.ops.scalar_compare}
#      1072    0.001    0.000    0.001    0.000 artist.py:317(get_transform)
#        87    0.001    0.000    0.001    0.000 transforms.py:2902(nonsingular)
#       700    0.001    0.000    0.001    0.000 Box2D.py:3338(<lambda>)
#       367    0.001    0.000    0.002    0.000 transforms.py:1039(__init__)
#       365    0.001    0.000    0.008    0.000 transforms.py:807(unit)
#        58    0.001    0.000    0.003    0.000 numeric.py:2522(within_tol)
#       357    0.001    0.000    0.016    0.000 patches.py:417(set_fill)
#      1400    0.001    0.000    0.001    0.000 Box2D.py:3825(__del__)
#      1400    0.001    0.000    0.004    0.000 Box2D.py:6001(__CreateBody)
#      1050    0.001    0.000    0.151    0.000 patches.py:736(get_patch_transform)
#      1089    0.001    0.000    0.027    0.000 artist.py:887(<listcomp>)
#       369    0.001    0.000    0.002    0.000 patches.py:351(set_linewidth)
#       700    0.001    0.000    0.001    0.000 Box2D.py:3848(shapes)
#       350    0.001    0.000    0.003    0.000 transforms.py:1868(transform_affine)
#       344    0.001    0.000    0.021    0.000 patches.py:335(set_alpha)
#       776    0.001    0.000    0.002    0.000 lines.py:62(_scale_dashes)
#      4900    0.001    0.000    0.001    0.000 arrayprint.py:239(_boolFormatter)
#        25    0.001    0.000    0.006    0.000 lines.py:290(__init__)
#         1    0.001    0.001    4.353    4.353 <string>:3(<module>)
#       451    0.001    0.000    0.002    0.000 artist.py:612(set_figure)
#      2100    0.001    0.000    0.001    0.000 {built-in method Box2D._Box2D.new_b2FixtureDef}
#       686    0.001    0.000    0.001    0.000 patches.py:701(get_path)
#       382    0.001    0.000    0.001    0.000 lines.py:34(_get_dash_pattern)
#       350    0.001    0.000    0.063    0.000 transforms.py:1356(contains_branch_seperately)
#      2526    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#       343    0.001    0.000    0.014    0.000 transforms.py:2474(transform_affine)
#      1400    0.001    0.000    0.001    0.000 {built-in method Box2D._Box2D.new_b2BodyDef}
#       361    0.001    0.000    0.001    0.000 patches.py:440(set_capstyle)
#       693    0.001    0.000    0.021    0.000 transforms.py:1673(__eq__)
#       386    0.001    0.000    0.002    0.000 __init__.py:2044(_to_unmasked_float_array)
#      1289    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#    102/51    0.001    0.000    0.001    0.000 units.py:141(get_converter)
#      2100    0.001    0.000    0.001    0.000 Box2D.py:3844(shapes)
#      1400    0.001    0.000    0.001    0.000 Box2D.py:3833(fixtures)
#      2090    0.001    0.000    0.001    0.000 transforms.py:2141(get_matrix)
#       826    0.001    0.000    0.001    0.000 artist.py:210(axes)
#        22    0.001    0.000    0.001    0.000 _base.py:2477(<listcomp>)
#       357    0.001    0.000    0.001    0.000 patches.py:457(set_joinstyle)
#       427    0.001    0.000    0.002    0.000 artist.py:303(set_transform)
#        22    0.000    0.000    0.000    0.000 _base.py:2478(<listcomp>)
#        22    0.000    0.000    0.029    0.001 _base.py:2451(autoscale_view)
#        29    0.000    0.000    0.001    0.000 _base.py:2495(<listcomp>)
#        58    0.000    0.000    0.005    0.000 numeric.py:2463(isclose)
#       445    0.000    0.000    0.001    0.000 <string>:12(__new__)
#       505    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#      1029    0.000    0.000    0.000    0.000 transforms.py:1950(get_matrix)
#       350    0.000    0.000    0.003    0.000 artist.py:814(set_alpha)
#       138    0.000    0.000    0.001    0.000 numeric.py:2667(seterr)
#       701    0.000    0.000    0.001    0.000 frame.py:7591(<genexpr>)
#       138    0.000    0.000    0.000    0.000 numeric.py:2767(geterr)
#       362    0.000    0.000    0.005    0.000 patches.py:288(set_edgecolor)
#      2786    0.000    0.000    0.000    0.000 transforms.py:1322(depth)
#       343    0.000    0.000    0.001    0.000 transforms.py:2739(get_matrix)
#      1623    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        24    0.000    0.000    0.001    0.000 cycler.py:349(by_key)
#        13    0.000    0.000    0.002    0.000 lines.py:649(recache)
#       116    0.000    0.000    0.001    0.000 fromnumeric.py:2275(amin)
#       350    0.000    0.000    0.001    0.000 patches.py:201(get_data_transform)
#       696    0.000    0.000    0.000    0.000 transforms.py:1747(_get_is_affine)
#        62    0.000    0.000    0.001    0.000 _base.py:3052(_validate_converted_limits)
#        35    0.000    0.000    0.000    0.000 stride_tricks.py:115(_broadcast_to)
#         7    0.000    0.000    0.001    0.000 function_base.py:432(histogram)
#       686    0.000    0.000    0.000    0.000 path.py:626(unit_rectangle)
#       362    0.000    0.000    0.014    0.000 patches.py:308(set_facecolor)
#        57    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.concatenate}
#       116    0.000    0.000    0.001    0.000 fromnumeric.py:2174(amax)
#        14    0.000    0.000    0.000    0.000 __init__.py:2369(normalize_kwargs)
#       358    0.000    0.000    0.001    0.000 patches.py:255(set_antialiased)
#        15    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        29    0.000    0.000    0.003    0.000 transforms.py:740(union)
#       674    0.000    0.000    0.000    0.000 transforms.py:991(get_points)
#     21/14    0.000    0.000    0.432    0.031 __init__.py:1786(inner)
#       350    0.000    0.000    0.003    0.000 transforms.py:1788(transform)
#       131    0.000    0.000    0.001    0.000 shape_base.py:11(atleast_1d)
#   192/191    0.000    0.000    0.000    0.000 common.py:1835(_get_dtype_type)
#       700    0.000    0.000    0.000    0.000 transforms.py:2355(get_matrix)
#      1057    0.000    0.000    0.000    0.000 path.py:208(vertices)
#       131    0.000    0.000    0.001    0.000 fromnumeric.py:1886(any)
#        16    0.000    0.000    0.004    0.000 _base.py:3071(set_xlim)
#       765    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       357    0.000    0.000    0.001    0.000 patches.py:474(set_hatch)
#     88/87    0.000    0.000    0.001    0.000 generic.py:4362(__getattr__)
#         7    0.000    0.000    0.451    0.064 distributions.py:42(distplot)
#       343    0.000    0.000    0.001    0.000 __init__.py:634(is_scalar_or_string)
#       343    0.000    0.000    0.000    0.000 transforms.py:2478(transform_non_affine)
#        20    0.000    0.000    0.001    0.000 __init__.py:332(connect)
#        79    0.000    0.000    0.001    0.000 printing.py:153(pprint_thing)
#        21    0.000    0.000    0.001    0.000 font_manager.py:668(__init__)
#       701    0.000    0.000    0.000    0.000 frame.py:7592(<genexpr>)
#        22    0.000    0.000    0.000    0.000 _base.py:4109(get_children)
#        10    0.000    0.000    0.001    0.000 base.py:255(__new__)
#        32    0.000    0.000    0.001    0.000 ticker.py:1871(_staircase)
#       198    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        15    0.000    0.000    0.002    0.000 _base.py:3391(set_ylim)
#        30    0.000    0.000    0.000    0.000 function_base.py:1848(diff)
#       337    0.000    0.000    0.000    0.000 generic.py:7(_check)
#       700    0.000    0.000    0.000    0.000 Box2D.py:3855(shapeFixture)
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#        19    0.000    0.000    0.002    0.000 series.py:166(__init__)
#        16    0.000    0.000    0.000    0.000 common.py:1965(pandas_dtype)
#        79    0.000    0.000    0.000    0.000 printing.py:182(as_escaped_unicode)
#        61    0.000    0.000    0.000    0.000 __init__.py:1566(get_siblings)
#       123    0.000    0.000    0.000    0.000 numeric.py:2135(isscalar)
#        16    0.000    0.000    0.001    0.000 ticker.py:1852(_validate_steps)
#         1    0.000    0.000    0.001    0.001 {pandas._libs.lib.fast_unique_multiple_list_gen}
#        27    0.000    0.000    0.001    0.000 text.py:129(__init__)
#        87    0.000    0.000    0.000    0.000 getlimits.py:376(__new__)
#         7    0.000    0.000    0.004    0.001 ops.py:1178(wrapper)
#        46    0.000    0.000    0.000    0.000 _base.py:3034(get_xlim)
#       147    0.000    0.000    0.000    0.000 base.py:61(is_dtype)
#         6    0.000    0.000    0.008    0.001 axis.py:74(__init__)
#        90    0.000    0.000    0.000    0.000 transforms.py:392(intervalx)
#    129/12    0.000    0.000    0.002    0.000 transforms.py:2427(_invalidate_internal)
#       588    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 legend.py:1299(_get_legend_handles)
#       222    0.000    0.000    0.000    0.000 traitlets.py:545(__get__)
#         1    0.000    0.000    0.000    0.000 frame.py:7597(<listcomp>)
#       145    0.000    0.000    0.001    0.000 {method 'any' of 'numpy.ndarray' objects}
#        43    0.000    0.000    0.000    0.000 _base.py:3373(get_ylim)
#        32    0.000    0.000    0.002    0.000 ticker.py:1879(set_params)
#       271    0.000    0.000    0.000    0.000 cycler.py:227(<genexpr>)
#       350    0.000    0.000    0.001    0.000 __init__.py:689(flatten)
#       256    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        30    0.000    0.000    0.001    0.000 _base.py:2158(_process_unit_info)
#       686    0.000    0.000    0.000    0.000 transforms.py:1814(get_affine)
#       764    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#        63    0.000    0.000    0.000    0.000 __init__.py:1493(clean)
#         7    0.000    0.000    0.003    0.000 _base.py:352(_plot_args)
#       138    0.000    0.000    0.000    0.000 {built-in method numpy.core.umath.seterrobj}
#        20    0.000    0.000    0.001    0.000 stride_tricks.py:195(broadcast_arrays)
#        29    0.000    0.000    0.000    0.000 _base.py:2499(<listcomp>)
#         7    0.000    0.000    0.001    0.000 container.py:109(<listcomp>)
#        14    0.000    0.000    0.000    0.000 __init__.py:350(_remove_proxy)
#         7    0.000    0.000    0.000    0.000 transforms.py:1070(get_points)
#        96    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_scalar}
#        86    0.000    0.000    0.000    0.000 transforms.py:400(intervaly)
#        40    0.000    0.000    0.000    0.000 __init__.py:160(__init__)
#        25    0.000    0.000    0.001    0.000 markers.py:251(set_marker)
#       343    0.000    0.000    0.000    0.000 patches.py:752(get_width)
#        20    0.000    0.000    0.000    0.000 stride_tricks.py:176(_broadcast_shape)
#        14    0.000    0.000    0.000    0.000 axis.py:338(_apply_params)
#         7    0.000    0.000    0.019    0.003 _axes.py:1288(plot)
#        50    0.000    0.000    0.000    0.000 lines.py:1025(_split_drawstyle_linestyle)
#         1    0.000    0.000    0.006    0.006 legend.py:306(__init__)
#        25    0.000    0.000    0.000    0.000 lines.py:1057(set_linestyle)
#        27    0.000    0.000    0.000    0.000 generic.py:4378(__setattr__)
#         7    0.000    0.000    0.017    0.002 base.py:3090(get_value)
#        68    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        34    0.000    0.000    0.000    0.000 text.py:178(update)
#         7    0.000    0.000    0.000    0.000 index_tricks.py:247(__getitem__)
#        19    0.000    0.000    0.000    0.000 font_manager.py:842(set_weight)
#        69    0.000    0.000    0.001    0.000 numeric.py:3069(__exit__)
#         7    0.000    0.000    0.017    0.002 {method 'get_value' of 'pandas._libs.index.IndexEngine' objects}
#        54    0.000    0.000    0.000    0.000 base.py:2033(__contains__)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.dicts_to_array}
#        69    0.000    0.000    0.001    0.000 numeric.py:3064(__enter__)
#        51    0.000    0.000    0.002    0.000 axis.py:1456(update_units)
#       353    0.000    0.000    0.000    0.000 artist.py:1049(mouseover)
#       350    0.000    0.000    0.000    0.000 artist.py:727(get_clip_path)
#        67    0.000    0.000    0.001    0.000 __init__.py:2348(safe_first_element)
#        28    0.000    0.000    0.001    0.000 ticker.py:1973(view_limits)
#         1    0.000    0.000    0.005    0.005 legend.py:887(_init_legend_box)
#        50    0.000    0.000    0.001    0.000 markers.py:200(_recache)
#        39    0.000    0.000    0.000    0.000 lines.py:619(axes)
#        16    0.000    0.000    0.000    0.000 version.py:307(parse)
#        69    0.000    0.000    0.000    0.000 numeric.py:3060(__init__)
#        58    0.000    0.000    0.000    0.000 type_check.py:221(isreal)
#       360    0.000    0.000    0.000    0.000 artist.py:296(is_transform_set)
#        11    0.000    0.000    0.000    0.000 cast.py:971(maybe_cast_to_datetime)
#        59    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.result_type}
#       350    0.000    0.000    0.000    0.000 path.py:260(should_simplify)
#        11    0.000    0.000    0.000    0.000 formatters.py:397(lookup_by_type)
#        77    0.000    0.000    0.000    0.000 formatters.py:550(_in_deferred_types)
#        29    0.000    0.000    0.000    0.000 _base.py:2502(<listcomp>)
#        15    0.000    0.000    0.000    0.000 shape_base.py:314(column_stack)
#         8    0.000    0.000    0.001    0.000 offsetbox.py:709(__init__)
#        18    0.000    0.000    0.000    0.000 html.py:64(_write_cell)
#         1    0.000    0.000    0.001    0.001 figure.py:283(__init__)
#        16    0.000    0.000    0.003    0.000 scale.py:68(set_default_locators_and_formatters)
#         5    0.000    0.000    0.000    0.000 internals.py:3363(_rebuild_blknos_and_blklocs)
#        25    0.000    0.000    0.000    0.000 internals.py:116(__init__)
#        16    0.000    0.000    0.000    0.000 ticker.py:501(__init__)
#         7    0.000    0.000    0.000    0.000 _methods.py:53(_mean)
#       222    0.000    0.000    0.000    0.000 traitlets.py:526(get)
#       307    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#       350    0.000    0.000    0.000    0.000 path.py:222(codes)
#         7    0.000    0.000    0.020    0.003 series.py:764(__getitem__)
#        16    0.000    0.000    0.002    0.000 transforms.py:961(intervalx)
#        57    0.000    0.000    0.000    0.000 range.py:481(__len__)
#         7    0.000    0.000    0.002    0.000 _base.py:1978(_update_line_limits)
#       350    0.000    0.000    0.000    0.000 artist.py:897(get_label)
#       276    0.000    0.000    0.000    0.000 {built-in method numpy.core.umath.geterrobj}
#        73    0.000    0.000    0.000    0.000 common.py:89(is_object_dtype)
#         7    0.000    0.000    0.004    0.001 _base.py:1949(add_line)
#        14    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         1    0.000    0.000    0.013    0.013 _base.py:1000(cla)
#        16    0.000    0.000    0.001    0.000 base.py:2067(__getitem__)
#        41    0.000    0.000    0.000    0.000 config.py:78(_get_single_key)
#       145    0.000    0.000    0.001    0.000 _methods.py:37(_any)
#        12    0.000    0.000    0.002    0.000 axis.py:801(cla)
#        25    0.000    0.000    0.001    0.000 internals.py:3191(make_block)
#        19    0.000    0.000    0.001    0.000 internals.py:4639(__init__)
#        23    0.000    0.000    0.000    0.000 generic.py:124(__init__)
#        82    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        41    0.000    0.000    0.000    0.000 base.py:2101(_can_hold_identifiers_and_holds_name)
#        29    0.000    0.000    0.000    0.000 transforms.py:364(xmax)
#        10    0.000    0.000    0.001    0.000 series.py:4019(_sanitize_array)
#       127    0.000    0.000    0.001    0.000 _methods.py:25(_amax)
#        29    0.000    0.000    0.000    0.000 transforms.py:350(xmin)
#        47    0.000    0.000    0.000    0.000 text.py:1159(set_text)
#       350    0.000    0.000    0.000    0.000 path.py:241(simplify_threshold)
#        16    0.000    0.000    0.000    0.000 {method 'split' of '_sre.SRE_Pattern' objects}
#        15    0.000    0.000    0.000    0.000 base.py:473(_simple_new)
#       125    0.000    0.000    0.001    0.000 _methods.py:28(_amin)
#        20    0.000    0.000    0.000    0.000 weakref.py:354(__init__)
#        16    0.000    0.000    0.000    0.000 axis.py:824(reset_ticks)
#         7    0.000    0.000    0.002    0.000 _base.py:295(_makeline)
#        20    0.000    0.000    0.000    0.000 internals.py:3148(get_block_type)
#        94    0.000    0.000    0.000    0.000 format.py:306(len)
#         9    0.000    0.000    0.000    0.000 {method 'sort' of 'numpy.ndarray' objects}
#        28    0.000    0.000    0.000    0.000 weakref.py:393(__getitem__)
#        15    0.000    0.000    0.004    0.000 _base.py:3004(set_xbound)
#         8    0.000    0.000    0.005    0.001 axis.py:844(set_tick_params)
#         1    0.000    0.000    0.018    0.018 _base.py:423(__init__)
#        25    0.000    0.000    0.000    0.000 lines.py:1170(set_markerfacecolor)
#        15    0.000    0.000    0.000    0.000 frame.py:2664(__getitem__)
#         6    0.000    0.000    0.000    0.000 algorithms.py:1548(take_nd)
#        29    0.000    0.000    0.000    0.000 transforms.py:371(ymax)
#        30    0.000    0.000    0.000    0.000 common.py:1688(is_extension_array_dtype)
#     28/24    0.000    0.000    0.000    0.000 spines.py:436(get_spine_transform)
#        40    0.000    0.000    0.000    0.000 font_manager.py:992(_normalize_font_family)
#        13    0.000    0.000    0.000    0.000 transforms.py:2069(scale)
#       326    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        15    0.000    0.000    0.000    0.000 transforms.py:966(intervaly)
#        27    0.000    0.000    0.000    0.000 internals.py:237(mgr_locs)
#        35    0.000    0.000    0.000    0.000 internals.py:4752(get_values)
#        79    0.000    0.000    0.000    0.000 inference.py:447(is_sequence)
#        28    0.000    0.000    0.000    0.000 __init__.py:2055(_check_1d)
#         4    0.000    0.000    0.000    0.000 encoder.py:204(iterencode)
#        14    0.000    0.000    0.002    0.000 _base.py:3344(set_ybound)
#        19    0.000    0.000    0.000    0.000 font_manager.py:860(set_stretch)
#         2    0.000    0.000    0.001    0.000 format.py:1023(get_result_as_array)
#        41    0.000    0.000    0.000    0.000 base.py:1590(is_object)
#       701    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        29    0.000    0.000    0.000    0.000 transforms.py:357(ymin)
#        50    0.000    0.000    0.000    0.000 internals.py:4718(dtype)
#        40    0.000    0.000    0.000    0.000 common.py:332(is_datetime64_dtype)
#         7    0.000    0.000    0.017    0.002 arrayprint.py:343(_array2string)
#        44    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        31    0.000    0.000    0.000    0.000 axis.py:779(limit_range_for_scale)
#      25/1    0.000    0.000    0.000    0.000 offsetbox.py:178(set_figure)
#        39    0.000    0.000    0.000    0.000 config.py:550(_get_root)
#        14    0.000    0.000    0.000    0.000 colors.py:233(to_rgba_array)
#        16    0.000    0.000    0.002    0.000 ticker.py:1803(__init__)
#        50    0.000    0.000    0.000    0.000 series.py:412(dtype)
#        72    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#        71    0.000    0.000    0.000    0.000 common.py:369(is_datetime64tz_dtype)
#        58    0.000    0.000    0.000    0.000 type_check.py:148(imag)
#        45    0.000    0.000    0.000    0.000 html.py:49(write)
#         4    0.000    0.000    0.001    0.000 spines.py:42(__init__)
#        24    0.000    0.000    0.000    0.000 dtypes.py:707(is_dtype)
#        80    0.000    0.000    0.000    0.000 config.py:565(_get_deprecated_option)
#        32    0.000    0.000    0.000    0.000 shape_base.py:288(<listcomp>)
#         7    0.000    0.000    0.001    0.000 _base.py:213(_xy_from_xy)
#        32    0.000    0.000    0.001    0.000 shape_base.py:239(hstack)
#        25    0.000    0.000    0.000    0.000 lines.py:1010(set_linewidth)
#        19    0.000    0.000    0.000    0.000 series.py:365(_set_axis)
#        24    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.empty}
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         8    0.000    0.000    0.000    0.000 axis.py:875(_translate_tick_kw)
#       105    0.000    0.000    0.000    0.000 internals.py:4684(_block)
#        25    0.000    0.000    0.000    0.000 lines.py:1381(set_dash_capstyle)
#         1    0.000    0.000    0.000    0.000 <string>:4(<dictcomp>)
#        70    0.000    0.000    0.000    0.000 __init__.py:1801(<genexpr>)
#       156    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        25    0.000    0.000    0.001    0.000 markers.py:167(__init__)
#        17    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.arange}
#         5    0.000    0.000    0.000    0.000 socket.py:337(send)
#        14    0.000    0.000    0.000    0.000 __init__.py:207(__call__)
#        25    0.000    0.000    0.000    0.000 lines.py:632(set_data)
#         2    0.000    0.000    0.000    0.000 format.py:1038(format_values_with)
#         7    0.000    0.000    0.000    0.000 internals.py:310(_slice)
#       6/1    0.000    0.000    0.000    0.000 jsonutil.py:109(json_clean)
#         7    0.000    0.000    0.000    0.000 _base.py:178(__call__)
#        25    0.000    0.000    0.001    0.000 offsetbox.py:147(__init__)
#         7    0.000    0.000    0.000    0.000 numerictypes.py:964(find_common_type)
#        75    0.000    0.000    0.000    0.000 axis.py:767(get_scale)
#        25    0.000    0.000    0.000    0.000 markers.py:226(set_fillstyle)
#         7    0.000    0.000    0.000    0.000 artist.py:963(update_from)
#        56    0.000    0.000    0.000    0.000 common.py:513(is_categorical_dtype)
#         7    0.000    0.000    0.000    0.000 arrayprint.py:299(_get_format_function)
#         7    0.000    0.000    0.017    0.002 arrayprint.py:381(wrapper)
#        17    0.000    0.000    0.003    0.000 axis.py:770(_set_scale)
#         7    0.000    0.000    0.000    0.000 artist.py:131(remove)
#        35    0.000    0.000    0.000    0.000 axis.py:764(get_transform)
#        25    0.000    0.000    0.000    0.000 lines.py:1182(set_markerfacecoloralt)
#        58    0.000    0.000    0.000    0.000 transforms.py:2145(transform)
#         7    0.000    0.000    0.000    0.000 numeric.py:179(_convert_scalar_indexer)
#        39    0.000    0.000    0.000    0.000 config.py:96(_get_option)
#        49    0.000    0.000    0.000    0.000 __init__.py:2364(sanitize_sequence)
#        38    0.000    0.000    0.000    0.000 _base.py:3178(get_xscale)
#        25    0.000    0.000    0.000    0.000 lines.py:1158(set_markeredgewidth)
#        25    0.000    0.000    0.000    0.000 lines.py:1194(set_markersize)
#        10    0.000    0.000    0.001    0.000 series.py:4036(_try_cast)
#        20    0.000    0.000    0.000    0.000 common.py:100(is_bool_indexer)
#        24    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.zeros}
#         7    0.000    0.000    0.017    0.002 arrayprint.py:399(array2string)
#         9    0.000    0.000    0.001    0.000 html.py:80(write_tr)
#         7    0.000    0.000    0.001    0.000 internals.py:4702(get_slice)
#        14    0.000    0.000    0.000    0.000 legend.py:858(get_legend_handler)
#        14    0.000    0.000    0.000    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
#        27    0.000    0.000    0.000    0.000 text.py:1209(set_usetex)
#         7    0.000    0.000    0.000    0.000 _base.py:253(_getdefaults)
#        47    0.000    0.000    0.000    0.000 series.py:401(name)
#         5    0.000    0.000    0.000    0.000 missing.py:189(_isna_ndarraylike)
#         1    0.000    0.000    0.000    0.000 {method 'get_labels' of 'pandas._libs.hashtable.StringHashTable' objects}
#        33    0.000    0.000    0.000    0.000 scale.py:82(get_transform)
#        35    0.000    0.000    0.000    0.000 series.py:476(get_values)
#         7    0.000    0.000    0.000    0.000 axis.py:1553(set_label_text)
#        17    0.000    0.000    0.000    0.000 axis.py:1588(set_major_locator)
#        29    0.000    0.000    0.000    0.000 transforms.py:747(<listcomp>)
#        15    0.000    0.000    0.000    0.000 transforms.py:2522(__init__)
#         7    0.000    0.000    0.002    0.000 series.py:875(_get_values)
#         7    0.000    0.000    0.001    0.000 base.py:520(_shallow_copy_with_infer)
#        61    0.000    0.000    0.000    0.000 __init__.py:1573(<listcomp>)
#         7    0.000    0.000    0.000    0.000 _base.py:2086(add_container)
#         7    0.000    0.000    0.000    0.000 offsetbox.py:581(__init__)
#        25    0.000    0.000    0.000    0.000 lines.py:715(set_transform)
#        25    0.000    0.000    0.000    0.000 lines.py:1342(set_dash_joinstyle)
#        14    0.000    0.000    0.000    0.000 format.py:997(base_formatter)
#        17    0.000    0.000    0.000    0.000 scale.py:560(scale_factory)
#        75    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        25    0.000    0.000    0.000    0.000 lines.py:989(set_drawstyle)
#        31    0.000    0.000    0.000    0.000 lines.py:1205(set_xdata)
#        25    0.000    0.000    0.000    0.000 lines.py:1395(set_solid_capstyle)
#         1    0.000    0.000    0.001    0.001 pyplot.py:416(figure)
#        35    0.000    0.000    0.000    0.000 internals.py:222(to_dense)
#        65    0.000    0.000    0.000    0.000 function_base.py:213(iterable)
#        51    0.000    0.000    0.000    0.000 offsetbox.py:246(get_children)
#        16    0.000    0.000    0.002    0.000 ticker.py:2493(__init__)
#        26    0.000    0.000    0.000    0.000 series.py:405(name)
#        44    0.000    0.000    0.000    0.000 generic.py:438(_info_axis)
#        12    0.000    0.000    0.000    0.000 axis.py:1529(set_units)
#        25    0.000    0.000    0.000    0.000 offsetbox.py:188(axes)
#         1    0.000    0.000    0.000    0.000 gridspec.py:84(get_grid_positions)
#        25    0.000    0.000    0.000    0.000 lines.py:1355(set_solid_joinstyle)
#         9    0.000    0.000    0.000    0.000 pyplot.py:580(gcf)
#         1    0.000    0.000    0.000    0.000 internals.py:4880(form_blocks)
#        29    0.000    0.000    0.000    0.000 missing.py:112(_isna_new)
#         1    0.000    0.000    0.000    0.000 function_base.py:25(linspace)
#        14    0.000    0.000    0.000    0.000 __init__.py:2477(get_label)
#         1    0.000    0.000    0.005    0.005 formatters.py:89(format)
#         7    0.000    0.000    0.001    0.000 range.py:260(_shallow_copy)
#        32    0.000    0.000    0.000    0.000 common.py:407(is_timedelta64_dtype)
#        81    0.000    0.000    0.000    0.000 stride_tricks.py:251(<genexpr>)
#        14    0.000    0.000    0.000    0.000 container.py:100(pchanged)
#        40    0.000    0.000    0.000    0.000 font_manager.py:996(<listcomp>)
#        33    0.000    0.000    0.000    0.000 transforms.py:983(minposx)
#         7    0.000    0.000    0.000    0.000 indexing.py:2345(check_bool_indexer)
#         4    0.000    0.000    0.003    0.001 frame.py:334(__init__)
#         8    0.000    0.000    0.000    0.000 numeric.py:35(__new__)
#        32    0.000    0.000    0.000    0.000 {pandas._libs.lib.values_from_object}
#         7    0.000    0.000    0.000    0.000 _methods.py:43(_count_reduce_items)
#         7    0.000    0.000    0.000    0.000 __init__.py:2070(_reshape_2D)
#     29/15    0.000    0.000    0.000    0.000 _base.py:768(get_yaxis_transform)
#        13    0.000    0.000    0.002    0.000 lines.py:950(get_path)
#        26    0.000    0.000    0.000    0.000 cycler.py:225(__iter__)
#         7    0.000    0.000    0.002    0.000 series.py:812(_get_with)
#        60    0.000    0.000    0.000    0.000 internals.py:352(dtype)
#        30    0.000    0.000    0.001    0.000 base.py:4914(_ensure_index)
#        29    0.000    0.000    0.000    0.000 missing.py:32(isna)
#        20    0.000    0.000    0.000    0.000 weakref.py:431(__contains__)
#         9    0.000    0.000    0.018    0.002 pyplot.py:951(gca)
#        25    0.000    0.000    0.000    0.000 artist.py:741(set_clip_on)
#        13    0.000    0.000    0.000    0.000 transforms.py:2761(__init__)
#         4    0.000    0.000    0.000    0.000 internals.py:4137(iget)
#         1    0.000    0.000    0.000    0.000 <string>:6(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 function_base.py:4689(delete)
#         7    0.000    0.000    0.000    0.000 arrayprint.py:256(_get_formatdict)
#        20    0.000    0.000    0.000    0.000 __init__.py:182(add_destroy_callback)
#        37    0.000    0.000    0.000    0.000 axis.py:1512(have_units)
#        18    0.000    0.000    0.000    0.000 axis.py:2087(get_minpos)
#        31    0.000    0.000    0.000    0.000 lines.py:1215(set_ydata)
#        29    0.000    0.000    0.000    0.000 transforms.py:748(<listcomp>)
#         9    0.000    0.000    0.000    0.000 dtypes.py:401(__new__)
#         4    0.000    0.000    0.000    0.000 core.py:2933(_update_from)
#        12    0.000    0.000    0.005    0.000 formatters.py:220(catch_format_error)
#        14    0.000    0.000    0.003    0.000 _base.py:400(_grab_next_args)
#        27    0.000    0.000    0.000    0.000 text.py:949(set_color)
#        29    0.000    0.000    0.000    0.000 transforms.py:749(<listcomp>)
#        15    0.000    0.000    0.000    0.000 frame.py:2690(_getitem_column)
#        63    0.000    0.000    0.000    0.000 base.py:641(__len__)
#         1    0.000    0.000    0.001    0.001 groupby.py:2493(_cython_operation)
#        46    0.000    0.000    0.000    0.000 common.py:122(is_sparse)
#         2    0.000    0.000    0.000    0.000 printing.py:12(adjoin)
#        37    0.000    0.000    0.000    0.000 _base.py:3498(get_yscale)
#         3    0.000    0.000    0.001    0.000 axis.py:494(_get_gridline)
#        17    0.000    0.000    0.000    0.000 axis.py:1566(set_major_formatter)
#        17    0.000    0.000    0.000    0.000 axis.py:1577(set_minor_formatter)
#         7    0.000    0.000    0.003    0.000 legend_handler.py:91(legend_artist)
#        19    0.000    0.000    0.000    0.000 font_manager.py:807(set_family)
#        15    0.000    0.000    0.000    0.000 internals.py:3307(shape)
#         7    0.000    0.000    0.000    0.000 stride_tricks.py:257(<listcomp>)
#         1    0.000    0.000    0.000    0.000 function_base.py:146(logspace)
#        55    0.000    0.000    0.000    0.000 __init__.py:377(process)
#         2    0.000    0.000    0.001    0.001 axis.py:705(__init__)
#         4    0.000    0.000    0.005    0.001 axis.py:1423(grid)
#         9    0.000    0.000    0.018    0.002 figure.py:1798(gca)
#        68    0.000    0.000    0.000    0.000 ticker.py:242(set_axis)
#        35    0.000    0.000    0.000    0.000 base.py:672(values)
#         3    0.000    0.000    0.000    0.000 cast.py:257(maybe_promote)
#        35    0.000    0.000    0.000    0.000 common.py:227(is_datetimetz)
#        94    0.000    0.000    0.000    0.000 __init__.py:275(strlen)
#         2    0.000    0.000    0.000    0.000 core.py:2959(__array_finalize__)
#         1    0.000    0.000    0.000    0.000 session.py:657(send)
#        14    0.000    0.000    0.000    0.000 __init__.py:185(_destroy)
#       106    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         3    0.000    0.000    0.001    0.000 axis.py:618(_get_gridline)
#        29    0.000    0.000    0.000    0.000 axis.py:1377(get_major_locator)
#        14    0.000    0.000    0.000    0.000 container.py:60(set_label)
#        29    0.000    0.000    0.000    0.000 transforms.py:750(<listcomp>)
#         2    0.000    0.000    0.000    0.000 format.py:386(__init__)
#        15    0.000    0.000    0.000    0.000 generic.py:2484(_get_item_cache)
#         9    0.000    0.000    0.000    0.000 dtypes.py:459(construct_from_string)
#        34    0.000    0.000    0.000    0.000 common.py:477(is_interval_dtype)
#         1    0.000    0.000    0.000    0.000 core.py:6559(power)
#         4    0.000    0.000    0.000    0.000 numeric.py:660(require)
#         9    0.000    0.000    0.003    0.000 formatters.py:331(__call__)
#        20    0.000    0.000    0.000    0.000 weakref.py:406(__setitem__)
#         1    0.000    0.000    0.000    0.000 {method 'writelines' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#        30    0.000    0.000    0.000    0.000 axis.py:331(_set_artist_props)
#         3    0.000    0.000    0.001    0.000 axis.py:468(_get_tick1line)
#         8    0.000    0.000    0.000    0.000 legend.py:716(_set_artist_props)
#         7    0.000    0.000    0.000    0.000 patches.py:170(update_from)
#         2    0.000    0.000    0.000    0.000 ticker.py:2199(nonsingular)
#        29    0.000    0.000    0.000    0.000 format.py:1385(just)
#         7    0.000    0.000    0.001    0.000 numeric.py:64(_shallow_copy)
#         3    0.000    0.000    0.001    0.000 base.py:2382(_format_with_header)
#         1    0.000    0.000    0.000    0.000 groupby.py:3114(_get_grouper)
#         4    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#        24    0.000    0.000    0.000    0.000 inference.py:251(is_list_like)
#        20    0.000    0.000    0.000    0.000 stride_tricks.py:247(<listcomp>)
#        14    0.000    0.000    0.000    0.000 _base.py:3336(get_ybound)
#         3    0.000    0.000    0.000    0.000 axis.py:435(_get_text1)
#         3    0.000    0.000    0.000    0.000 axis.py:559(_get_text1)
#         3    0.000    0.000    0.001    0.000 axis.py:589(_get_tick1line)
#         1    0.000    0.000    0.000    0.000 scale.py:100(transform_non_affine)
#        19    0.000    0.000    0.000    0.000 font_manager.py:820(set_style)
#        25    0.000    0.000    0.000    0.000 lines.py:967(set_antialiased)
#        16    0.000    0.000    0.000    0.000 artist.py:924(set_zorder)
#        29    0.000    0.000    0.000    0.000 transforms.py:286(__array__)
#         7    0.000    0.000    0.000    0.000 ops.py:50(get_op_result_name)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.clean_index_list}
#        39    0.000    0.000    0.000    0.000 config.py:606(_warn_if_deprecated)
#        11    0.000    0.000    0.000    0.000 formatters.py:374(lookup)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#        75    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         3    0.000    0.000    0.001    0.000 axis.py:479(_get_tick2line)
#         3    0.000    0.000    0.001    0.000 axis.py:604(_get_tick2line)
#        15    0.000    0.000    0.000    0.000 axis.py:2466(get_minpos)
#         4    0.000    0.000    0.001    0.000 spines.py:485(linear_spine)
#     29/15    0.000    0.000    0.000    0.000 _base.py:688(get_xaxis_transform)
#        15    0.000    0.000    0.000    0.000 _base.py:2996(get_xbound)
#        29    0.000    0.000    0.000    0.000 transforms.py:987(minposy)
#        15    0.000    0.000    0.000    0.000 transforms.py:1998(clear)
#         2    0.000    0.000    0.000    0.000 indexing.py:970(_getitem_lowerdim)
#         7    0.000    0.000    0.001    0.000 range.py:491(__getitem__)
# ...
#         1    0.000    0.000    0.000    0.000 {built-in method utcnow}
#         2    0.000    0.000    0.000    0.000 {built-in method binascii.b2a_hex}
#         2    0.000    0.000    0.000    0.000 threading.py:251(_acquire_restore)
#         2    0.000    0.000    0.000    0.000 threading.py:254(_is_owned)
#         7    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:861(_find_spec_legacy)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#        18    0.000    0.000    0.000    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#         2    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 html.py:202(_column_header)
#         1    0.000    0.000    0.000    0.000 scale.py:96(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:52(get_projection_class)
#         1    0.000    0.000    0.000    0.000 _base.py:964(_gen_axes_patch)
#         1    0.000    0.000    0.000    0.000 figure.py:109(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 figure.py:108(_entry_from_axes)
#         1    0.000    0.000    0.000    0.000 figure.py:116(bubble)
#         1    0.000    0.000    0.000    0.000 figure.py:168(__contains__)
#         1    0.000    0.000    0.000    0.000 figure.py:79(__init__)
#         1    0.000    0.000    0.000    0.000 offsetbox.py:203(set_offset)
#         1    0.000    0.000    0.000    0.000 gridspec.py:391(__init__)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:35(get_fig_manager)
#         2    0.000    0.000    0.000    0.000 legend.py:823(get_default_handler_map)
#         2    0.000    0.000    0.000    0.000 patches.py:1993(__init__)
#         3    0.000    0.000    0.000    0.000 text.py:1114(set_x)
#         3    0.000    0.000    0.000    0.000 text.py:1123(set_y)
#         1    0.000    0.000    0.000    0.000 gridspec.py:41(__init__)
#         3    0.000    0.000    0.000    0.000 gridspec.py:51(get_geometry)
#         1    0.000    0.000    0.000    0.000 artist.py:523(set_snap)
#         2    0.000    0.000    0.000    0.000 six.py:184(find_module)
#         2    0.000    0.000    0.000    0.000 ticker.py:2075(base)
#         2    0.000    0.000    0.000    0.000 format.py:356(should_show_dimensions)
#         2    0.000    0.000    0.000    0.000 format.py:982(_value_formatter)
#         2    0.000    0.000    0.000    0.000 series.py:470(_formatting_values)
#         1    0.000    0.000    0.000    0.000 internals.py:3351(_is_single_block)
#         2    0.000    0.000    0.000    0.000 internals.py:3473(__len__)
#         2    0.000    0.000    0.000    0.000 internals.py:5020(_asarray_compat)
#         6    0.000    0.000    0.000    0.000 indexing.py:229(<genexpr>)
#         2    0.000    0.000    0.000    0.000 internals.py:209(formatting_values)
#         1    0.000    0.000    0.000    0.000 internals.py:251(make_block)
#         4    0.000    0.000    0.000    0.000 internals.py:348(shape)
#         1    0.000    0.000    0.000    0.000 internals.py:750(_try_coerce_and_cast_result)
#         1    0.000    0.000    0.000    0.000 generic.py:349(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 generic.py:394(_get_block_manager_axis)
#         1    0.000    0.000    0.000    0.000 generic.py:1675(_repr_latex_)
#         1    0.000    0.000    0.000    0.000 range.py:169(_data)
#         4    0.000    0.000    0.000    0.000 base.py:711(get_values)
#         1    0.000    0.000    0.000    0.000 base.py:1332(_set_names)
#         1    0.000    0.000    0.000    0.000 base.py:1425(rename)
#         2    0.000    0.000    0.000    0.000 base.py:4132(_validate_indexer)
#         1    0.000    0.000    0.000    0.000 groupby.py:756(__getattr__)
#         1    0.000    0.000    0.000    0.000 groupby.py:2196(__init__)
#         1    0.000    0.000    0.001    0.001 groupby.py:2360(ngroups)
#         1    0.000    0.000    0.000    0.000 groupby.py:2456(get_func)
#         2    0.000    0.000    0.000    0.000 groupby.py:3067(labels)
#         2    0.000    0.000    0.000    0.000 groupby.py:3089(group_index)
#         1    0.000    0.000    0.000    0.000 groupby.py:3327(_is_label_like)
#         1    0.000    0.000    0.002    0.002 base.py:76(__repr__)
#         1    0.000    0.000    0.000    0.000 function.py:326(validate_groupby_func)
#         1    0.000    0.000    0.000    0.000 _validators.py:114(_check_for_invalid_keys)
#         7    0.000    0.000    0.000    0.000 {built-in method pandas._libs.algos.ensure_platform_int}
#         1    0.000    0.000    0.000    0.000 inference.py:287(is_array_like)
#         1    0.000    0.000    0.000    0.000 algorithms.py:172(_ensure_arraylike)
#         1    0.000    0.000    0.000    0.000 version.py:63(__gt__)
#         1    0.000    0.000    0.000    0.000 core.py:1718(mask_or)
#         2    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 tz.py:212(utcoffset)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:34(_ensure_tzinfo)
#         1    0.000    0.000    0.000    0.000 iostream.py:207(send_multipart)
#         1    0.000    0.000    0.000    0.000 iostream.py:260(send_multipart)
#         2    0.000    0.000    0.000    0.000 __init__.py:1445(is_interactive)
#         1    0.000    0.000    0.000    0.000 __init__.py:1178(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:1485(__init__)
#         1    0.000    0.000    0.000    0.000 displaypub.py:38(_validate_data)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:698(get_ipython)
#         1    0.000    0.000    0.000    0.000 pretty.py:482(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:1161(getLogger)
#         1    0.000    0.000    0.000    0.000 __init__.py:228(_releaseLock)
#         2    0.000    0.000    0.000    0.000 threading.py:248(_release_save)
#         1    0.000    0.000    0.000    0.000 re.py:184(sub)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1149(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#       3/1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         9    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#        13    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#        13    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 html.py:317(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _base.py:3744(set_navigate)
#         1    0.000    0.000    0.000    0.000 _base.py:3762(set_navigate_mode)
#         1    0.000    0.000    0.000    0.000 _base.py:4291(get_shared_x_axes)
#         6    0.000    0.000    0.000    0.000 axis.py:172(<dictcomp>)
#        14    0.000    0.000    0.000    0.000 axis.py:363(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 axis.py:1439(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 _base.py:932(set_axes_locator)
#         1    0.000    0.000    0.000    0.000 _base.py:2980(set_axis_on)
#         1    0.000    0.000    0.000    0.000 __init__.py:25(get_projection_class)
#         1    0.000    0.000    0.000    0.000 _subplots.py:201(subplot_class_factory)
#         1    0.000    0.000    0.000    0.000 widgets.py:37(__init__)
#         1    0.000    0.000    0.000    0.000 legend.py:1148(set_bbox_to_anchor)
#         1    0.000    0.000    0.000    0.000 offsetbox.py:778(set_minimumdescent)
#         1    0.000    0.000    0.000    0.000 gridspec.py:66(set_width_ratios)
#         1    0.000    0.000    0.000    0.000 gridspec.py:75(set_height_ratios)
#         1    0.000    0.000    0.000    0.000 gridspec.py:143(_normalize)
#         2    0.000    0.000    0.000    0.000 legend.py:792(_approx_text_height)
#         2    0.000    0.000    0.000    0.000 patches.py:1911(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 patches.py:269(set_aa)
#         7    0.000    0.000    0.000    0.000 lines.py:864(get_color)
#         1    0.000    0.000    0.000    0.000 transforms.py:418(height)
#         1    0.000    0.000    0.000    0.000 format.py:809(has_column_names)
#        16    0.000    0.000    0.000    0.000 format.py:1078(<genexpr>)
#         2    0.000    0.000    0.000    0.000 format.py:1604(<genexpr>)
#         1    0.000    0.000    0.000    0.000 common.py:95(_expand_user)
#         1    0.000    0.000    0.000    0.000 internals.py:3405(<listcomp>)
#         1    0.000    0.000    0.000    0.000 internals.py:3845(<listcomp>)
#         1    0.000    0.000    0.000    0.000 internals.py:4990(<lambda>)
#         1    0.000    0.000    0.000    0.000 internals.py:229(fill_value)
#         1    0.000    0.000    0.000    0.000 internals.py:685(convert)
#         1    0.000    0.000    0.000    0.000 frame.py:7621(<listcomp>)
#         1    0.000    0.000    0.000    0.000 range.py:158(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:4977(_ensure_has_len)
#         1    0.000    0.000    0.000    0.000 groupby.py:4757(_reindex_output)
#         4    0.000    0.000    0.000    0.000 base.py:662(dtype)
#         3    0.000    0.000    0.000    0.000 base.py:1325(nlevels)
#         1    0.000    0.000    0.000    0.000 base.py:1569(is_unique)
#         1    0.000    0.000    0.000    0.000 base.py:2465(identical)
#         1    0.000    0.000    0.000    0.000 base.py:3559(_can_reindex)
#         1    0.000    0.000    0.000    0.000 groupby.py:2351(<listcomp>)
#         1    0.000    0.000    0.000    0.000 groupby.py:3073(result_index)
#         2    0.000    0.000    0.000    0.000 groupby.py:3229(<genexpr>)
#         1    0.000    0.000    0.000    0.000 groupby.py:3258(is_in_axis)
#         1    0.000    0.000    0.000    0.000 common.py:154(_all_none)
#         1    0.000    0.000    0.000    0.000 common.py:178(_count_not_none)
#         1    0.000    0.000    0.000    0.000 common.py:489(in_interactive_session)
#         1    0.000    0.000    0.001    0.001 _decorators.py:185(wrapper)
#         1    0.000    0.000    0.000    0.000 _validators.py:32(_check_for_default_values)
#         1    0.000    0.000    0.000    0.000 _validators.py:221(validate_bool_kwarg)
#         1    0.000    0.000    0.000    0.000 missing.py:485(_maybe_fill)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.algos.ensure_float64}
#         1    0.000    0.000    0.000    0.000 inference.py:388(is_named_tuple)
#         1    0.000    0.000    0.000    0.000 common.py:1717(is_complex_dtype)
#         4    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_bool}
#         2    0.000    0.000    0.000    0.000 config.py:582(_get_registered_option)
#         1    0.000    0.000    0.000    0.000 core.py:1583(make_mask)
#         2    0.000    0.000    0.000    0.000 core.py:3226(_scalar_heuristic)
#         1    0.000    0.000    0.000    0.000 jsonutil.py:49(encode_images)
#         1    0.000    0.000    0.000    0.000 tz.py:256(_isdst)
#         1    0.000    0.000    0.000    0.000 session.py:509(msg_id)
#         1    0.000    0.000    0.000    0.000 session.py:739(<listcomp>)
#         1    0.000    0.000    0.000    0.000 hmac.py:108(_current)
#         1    0.000    0.000    0.000    0.000 __init__.py:1431(get_backend)
#         1    0.000    0.000    0.000    0.000 formatters.py:824(_check_return)
#         1    0.000    0.000    0.000    0.000 decorator.py:decorator-gen-11>:1(__call__)
#         1    0.000    0.000    0.000    0.000 decorator.py:decorator-gen-12>:1(__call__)
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 configurable.py:426(initialized)
#         1    0.000    0.000    0.000    0.000 py3compat.py:19(encode)
#         1    0.000    0.000    0.000    0.000 copyreg.py:87(__newobj__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1080(_path_importer_cache)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:707(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:780(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:41(_relax_case)
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 scale.py:284(get_transform)
#         1    0.000    0.000    0.000    0.000 _base.py:2480(<listcomp>)
#         1    0.000    0.000    0.000    0.000 figure.py:767(set_canvas)
#         1    0.000    0.000    0.000    0.000 figure.py:1026(fixitems)
#         1    0.000    0.000    0.000    0.000 _subplots.py:123(get_subplotspec)
#         2    0.000    0.000    0.000    0.000 figure.py:517(get_constrained_layout)
#         2    0.000    0.000    0.000    0.000 figure.py:87(<listcomp>)
#         2    0.000    0.000    0.000    0.000 figure.py:89(<listcomp>)
#         1    0.000    0.000    0.000    0.000 legend.py:1079(get_frame)
#         1    0.000    0.000    0.000    0.000 gridspec.py:428(get_gridspec)
#         1    0.000    0.000    0.000    0.000 legend.py:844(get_legend_handler_map)
#         2    0.000    0.000    0.000    0.000 patches.py:1910(<listcomp>)
#         1    0.000    0.000    0.000    0.000 font_manager.py:784(get_size_in_points)
#         2    0.000    0.000    0.000    0.000 artist.py:711(get_visible)
#         1    0.000    0.000    0.000    0.000 transforms.py:2226(_get_is_affine)
#         1    0.000    0.000    0.000    0.000 internals.py:3561(<genexpr>)
#         7    0.000    0.000    0.000    0.000 internals.py:3776(is_consolidated)
#         1    0.000    0.000    0.000    0.000 internals.py:746(_try_coerce_result)
#         1    0.000    0.000    0.000    0.000 generic.py:1294(<listcomp>)
#         1    0.000    0.000    0.000    0.000 groupby.py:2301(<listcomp>)
#         2    0.000    0.000    0.000    0.000 frame.py:320(_constructor)
#         3    0.000    0.000    0.000    0.000 missing.py:74(clean_fill_method)
#         2    0.000    0.000    0.000    0.000 base.py:719(ndim)
#         3    0.000    0.000    0.000    0.000 common.py:180(<genexpr>)
#         1    0.000    0.000    0.000    0.000 __init__.py:259(u)
#         2    0.000    0.000    0.000    0.000 shape_base.py:897(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.normalize_axis_index}
#         1    0.000    0.000    0.002    0.002 decorator.py:decorator-gen-10>:1(__call__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# %%prun

class QModel(T.nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        self.in_features = T.nn.Linear(6, hidden_size)
        d = .2 * (self.in_features.in_features) ** -.5
        T.nn.init.uniform_(self.in_features.weight, -d, d)
        self.predict = T.nn.Linear(hidden_size, 4)

    def forward(self, x):
        h = T.relu(self.in_features(x))
        return self.predict(h)

class QAgent:
    def __init__(self):
        # Fixed state (settings)
        self.discount = .95
        self.ticks_per_action = 10
        self.greed = .9
        self.qsteps = 5
        self.max_buffer = 1000
        self.update_sample = 100
        self.max_game_time = 20
        self.actions = [(False, False), (False, True), (True, False), (True, True)]

        # Transient state
        self.model = QModel(10)
        self.buffer = []
        self.random = np.random.RandomState()
        self.pre_buffer = []
        self.opt = T.optim.Adam(self.model.parameters())
        self.log = Log()

    def _update(self):
        if self.update_sample <= len(self.buffer):
            self.opt.zero_grad()
            indices = self.random.randint(0, len(self.buffer), self.update_sample)
            states = T.FloatTensor([self.buffer[idx][0] for idx in indices])
            actions = T.LongTensor([self.buffer[idx][1] for idx in indices])
            rewards = T.FloatTensor([self.buffer[idx][2] for idx in indices])

            y = self.model(states)[T.arange(self.update_sample), actions]
            loss = ((y - rewards) ** 2).sum()
            self.log.append('loss', float(loss))
            loss.backward()
            self.opt.step()

    def _act(self, state, greedy):
        if greedy or self.random.rand() < self.greed:
            return int(T.argmax(self.model(T.FloatTensor(state))))
        else:
            return self.random.randint(len(self.actions))

    def _add_memory(self, state, action, reward):
        if self.qsteps == len(self.pre_buffer):
            sar = self.pre_buffer.pop(0)
            sar[2] += (self.discount ** self.qsteps) * float(T.max(self.model(T.FloatTensor(state))))
            self.buffer.append(sar)
        self.pre_buffer.append([state, action, 0])
        for n in range(len(self.pre_buffer)):
            self.pre_buffer[-1 - n][2] += reward * (self.discount ** n)
        self._update()

    def _flush_and_trim_buffer(self):
        self.buffer += self.pre_buffer
        self.pre_buffer = []
        self.buffer = self.buffer[-self.max_buffer:]

    def train(self):
        """Train the agent with a single game."""
        game = H.Game()
        assert H.in_bounds(game.state), 'should always start in bounds'
        while True:
            state = game.state
            action = self._act(state, greedy=False)
            for _ in range(self.ticks_per_action):
                game.step(*self.actions[action])
                timed_out = self.max_game_time <= game.elapsed
                if timed_out or not H.in_bounds(game.state):
                    self._add_memory(state, action, timed_out)
                    self._flush_and_trim_buffer()
                    self.log.append('gamelength', game.elapsed)
                    self.log.append('survived', timed_out)
                    self.log.tick()
                    return
            self._add_memory(state, action, 1)
            self.log.tick()

    def __call__(self, state):
        """Evaluation policy - greedy as anything."""
        return self.actions[self._act(state, greedy=True)]

game = H.Game()
agent = QAgent()
for _ in range(1000):  # 1000
    agent.train()
agent.log.show()

# qdf = pd.DataFrame.from_dict(
#     [dict(name=name, lifetime=H.single_game_lifetime(agent, 20))
#      for name, agent in [('untrained', QAgent()),
#                          ('trained', agent)]
#      for _ in range(100)])
# plot_lifetime_dist(qdf)

# %%
game = H.Game()
display_id = display(game, display_id=True)
while H.in_bounds(game.state):
    for _ in range(10):
        game.step(*agent(game.state))
    display_id.update(game)
    time.sleep(10 * game.timestep)
# Out:
# <svg viewBox="-30 -1 60 30" width="800" height="400.0"><g transform="scale(1,-1) translate(0, -28)"><g transform="translate(0.0,-10.0) rotate(0.0)"><path fill="black" d="M -50.0 -10.0 L 50.0 -10.0 L 50.0 10.0 L -50.0 10.0"/></g><g transform="translate(-1.3619351387023926,9.408306121826172) rotate(10.532680186046692)"><path fill="blue" d="M -0.4000000059604645 -2.0 L 0.4000000059604645 -2.0 L 0.4000000059604645 2.0 L -0.4000000059604645 2.0"/></g></g></svg>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-12a7172f7a92> in <module>
#       5         game.step(*agent(game.state))
#       6     display_id.update(game)
# ----> 7     time.sleep(10 * game.timestep)
#
# KeyboardInterrupt:
